# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [0.99276343 0.61104908 0.80350163 0.93136984 1.92162029 0.53282559
#  0.86365447 2.77887097 1.80744963 2.60012021 1.72041195 2.2840179
#  2.44659313 2.73319595 1.38728398 2.39333037 2.35323705 2.31822907
#  2.748177   3.15036069 2.7074072  3.7526142  3.72259165 4.50595025
#  4.1361905  4.3836067  3.97859242 3.69798801 4.74244323 4.22245621
#  4.5970985  6.22762998 3.60176382 4.44059095 4.85486364 4.87407846
#  4.87561935 3.97292269 4.71628346 5.10215783 5.87371737 6.03393561
#  5.71524901 5.09976155 5.74505701 5.93609089 6.71460675 6.00924022
#  5.87567424 6.2743504 ]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.89458737 1.00808878 1.12159019 1.2350916  1.34859301 1.46209442
#  1.57559583 1.68909724 1.80259864 1.91610005 2.02960146 2.14310287
#  2.25660428 2.37010569 2.4836071  2.5971085  2.71060991 2.82411132
#  2.93761273 3.05111414 3.16461555 3.27811696 3.39161837 3.50511977
#  3.61862118 3.73212259 3.845624   3.95912541 4.07262682 4.18612823
#  4.29962963 4.41313104 4.52663245 4.64013386 4.75363527 4.86713668
#  4.98063809 5.0941395  5.2076409  5.32114231 5.43464372 5.54814513
#  5.66164654 5.77514795 5.88864936 6.00215076 6.11565217 6.22915358
#  6.34265499 6.4561564 ]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.3171935696153059

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.1123138])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.8945873744369011

# %%
Y
# Out:
# array([0.89458737, 1.00808878, 1.12159019, 1.2350916 , 1.34859301,
#        1.46209442, 1.57559583, 1.68909724, 1.80259864, 1.91610005,
#        2.02960146, 2.14310287, 2.25660428, 2.37010569, 2.4836071 ,
#        2.5971085 , 2.71060991, 2.82411132, 2.93761273, 3.05111414,
#        3.16461555, 3.27811696, 3.39161837, 3.50511977, 3.61862118,
#        3.73212259, 3.845624  , 3.95912541, 4.07262682, 4.18612823,
#        4.29962963, 4.41313104, 4.52663245, 4.64013386, 4.75363527,
#        4.86713668, 4.98063809, 5.0941395 , 5.2076409 , 5.32114231,
#        5.43464372, 5.54814513, 5.66164654, 5.77514795, 5.88864936,
#        6.00215076, 6.11565217, 6.22915358, 6.34265499, 6.4561564 ])

# %%
#可以將新的x資料帶入算出結果
W*0.81632653 +b
# Out:
# array([1.80259864])

# %%
y
# Out:
# array([0.99276343, 0.61104908, 0.80350163, 0.93136984, 1.92162029,
#        0.53282559, 0.86365447, 2.77887097, 1.80744963, 2.60012021,
#        1.72041195, 2.2840179 , 2.44659313, 2.73319595, 1.38728398,
#        2.39333037, 2.35323705, 2.31822907, 2.748177  , 3.15036069,
#        2.7074072 , 3.7526142 , 3.72259165, 4.50595025, 4.1361905 ,
#        4.3836067 , 3.97859242, 3.69798801, 4.74244323, 4.22245621,
#        4.5970985 , 6.22762998, 3.60176382, 4.44059095, 4.85486364,
#        4.87407846, 4.87561935, 3.97292269, 4.71628346, 5.10215783,
#        5.87371737, 6.03393561, 5.71524901, 5.09976155, 5.74505701,
#        5.93609089, 6.71460675, 6.00924022, 5.87567424, 6.2743504 ])
